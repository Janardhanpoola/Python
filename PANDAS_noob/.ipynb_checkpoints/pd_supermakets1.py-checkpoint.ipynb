# %%
import pandas as pd

# %%
df1=pd.read_csv("supermarkets.csv")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pd.read_json("supermarkets.json")

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pd.read_csv("supermarkets-commas.txt")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4=pd.read_csv("supermarkets-semi-colons.txt")
df4
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %% [markdown]
# Setting header
# ->set header if there is no header in a dataframe

# %%
df7=pd.read_csv("data.txt",header=None)
df7
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df7.columns=["ID","ADDRESS","STATE","ZIP","COUNTRY","STREET","CODE"]

# %% [markdown]
# Setting columns

# %%
df7
# Out:
#             ADDRESS          STATE               ZIP COUNTRY       STREET  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     CODE
# ID
# 1      8
# 2     15
# 3     25
# 4     10
# 5     12
# 6     20

# %% [markdown]
# setting row index

# %%
df7.set_index("ID",inplace=True)

# %%
df7
# Out:
#             ADDRESS          STATE               ZIP COUNTRY       STREET  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     CODE
# ID
# 1      8
# 2     15
# 3     25
# 4     10
# 5     12
# 6     20

# %%
df7.set_index("ADDRESS",drop=False)
# Out:
#                          ADDRESS          STATE               ZIP COUNTRY  \
# ADDRESS
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                       STREET  CODE
# ADDRESS
# 3666 21st St         Madeira     8
# 735 Dolores St   Bready Shop    15
# 332 Hill St      Super River    25
# 3995 23rd St      Ben's Shop    10
# 1056 Sanchez St      Sanchez    12
# 551 Alvarado St   Richvalley    20

# %% [markdown]
# # slicing and indexing(label based indexing)

# %%
df7
# Out:
#             ADDRESS          STATE               ZIP COUNTRY       STREET  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     CODE
# ID
# 1      8
# 2     15
# 3     25
# 4     10
# 5     12
# 6     20

# %%
df7.set_index("ADDRESS",inplace=True)

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20

# %%
df7.loc["3995 23rd St",:]
# Out:
# STATE      San Francisco
# ZIP             CA 94114
# COUNTRY              USA
# STREET        Ben's Shop
# CODE                  10
# Name: 3995 23rd St, dtype: object

# %%
df7.loc[:,"COUNTRY":"CODE"]
# Out:
#                 COUNTRY       STREET  CODE
# ADDRESS
# 3666 21st St        USA      Madeira     8
# 735 Dolores St      USA  Bready Shop    15
# 332 Hill St         USA  Super River    25
# 3995 23rd St        USA   Ben's Shop    10
# 1056 Sanchez St     USA      Sanchez    12
# 551 Alvarado St     USA   Richvalley    20

# %% [markdown]
# # position based indexing

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20

# %%
df7.iloc[1:4,2:5]
# Out:
#                COUNTRY       STREET  CODE
# ADDRESS
# 735 Dolores St     USA  Bready Shop    15
# 332 Hill St        USA  Super River    25
# 3995 23rd St       USA   Ben's Shop    10

# %%
df7.iloc[2:,:2]
# Out:
#                          STATE               ZIP
# ADDRESS
# 332 Hill St      San Francisco  California 94114
# 3995 23rd St     San Francisco          CA 94114
# 1056 Sanchez St  San Francisco        California
# 551 Alvarado St  San Francisco          CA 94114

# %% [markdown]
# # deleting columns and rows

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20

# %%
df7.drop("ZIP",1)#specify 1 for column,0 for index and inplace=True to delete
# Out:
#                          STATE COUNTRY       STREET  CODE
# ADDRESS
# 3666 21st St     San Francisco     USA      Madeira     8
# 735 Dolores St   San Francisco     USA  Bready Shop    15
# 332 Hill St      San Francisco     USA  Super River    25
# 3995 23rd St     San Francisco     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco     USA      Sanchez    12
# 551 Alvarado St  San Francisco     USA   Richvalley    20

# %%
df7.drop("3666 21st St",0)
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE
# ADDRESS
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20

# %%
df7.drop(df7.index[1:3],0)#delete by index
# Out:
#                          STATE         ZIP COUNTRY      STREET  CODE
# ADDRESS
# 3666 21st St     San Francisco    CA 94114     USA     Madeira     8
# 3995 23rd St     San Francisco    CA 94114     USA  Ben's Shop    10
# 1056 Sanchez St  San Francisco  California     USA     Sanchez    12
# 551 Alvarado St  San Francisco    CA 94114     USA  Richvalley    20

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20

# %%
df7.drop(df7.columns[1:4],1)
# Out:
#                          STATE  CODE
# ADDRESS
# 3666 21st St     San Francisco     8
# 735 Dolores St   San Francisco    15
# 332 Hill St      San Francisco    25
# 3995 23rd St     San Francisco    10
# 1056 Sanchez St  San Francisco    12
# 551 Alvarado St  San Francisco    20

# %% [markdown]
# # Adding rows and columns

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20

# %% [markdown]
# Adding column

# %%
df7["Continent"]="North America"

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20
#
#                      Continent
# ADDRESS
# 3666 21st St     North America
# 735 Dolores St   North America
# 332 Hill St      North America
# 3995 23rd St     North America
# 1056 Sanchez St  North America
# 551 Alvarado St  North America

# %% [markdown]
# modifying column

# %%
df7["Continent"]=df7["COUNTRY"]+","+"North America"

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20
#
#                          Continent
# ADDRESS
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 332 Hill St      USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# 551 Alvarado St  USA,North America

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET  CODE  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira     8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop    15
# 332 Hill St      San Francisco  California 94114     USA  Super River    25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop    10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez    12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley    20
#
#                          Continent
# ADDRESS
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 332 Hill St      USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# 551 Alvarado St  USA,North America

# %% [markdown]
# Adding  Rows

# %%
df7_t=df7.T

# %%
df7_t
# Out:
# ADDRESS         3666 21st St     735 Dolores St        332 Hill St  \
# STATE          San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119   California 94114
# COUNTRY                  USA                USA                USA
# STREET               Madeira        Bready Shop        Super River
# CODE                       8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# ADDRESS         3995 23rd St    1056 Sanchez St    551 Alvarado St
# STATE          San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114         California           CA 94114
# COUNTRY                  USA                USA                USA
# STREET            Ben's Shop            Sanchez         Richvalley
# CODE                      10                 12                 20
# Continent  USA,North America  USA,North America  USA,North America

# %%
df7_t["332 jesus st"]=["Arizona",9894,"USA","hellno st",78,"NA"]

# %%
df7_t
# Out:
# ADDRESS         3666 21st St     735 Dolores St        332 Hill St  \
# STATE          San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119   California 94114
# COUNTRY                  USA                USA                USA
# STREET               Madeira        Bready Shop        Super River
# CODE                       8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# ADDRESS         3995 23rd St    1056 Sanchez St    551 Alvarado St  \
# STATE          San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114         California           CA 94114
# COUNTRY                  USA                USA                USA
# STREET            Ben's Shop            Sanchez         Richvalley
# CODE                      10                 12                 20
# Continent  USA,North America  USA,North America  USA,North America
#
# ...

# %%
df7=df7_t.T

# %%
df7
# Out:
#                          STATE               ZIP COUNTRY       STREET CODE  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira    8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop   15
# 332 Hill St      San Francisco  California 94114     USA  Super River   25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop   10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez   12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley   20
# 332 jesus st           Arizona              9894     USA    hellno st   78
#
#                          Continent
# ADDRESS
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 332 Hill St      USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# 551 Alvarado St  USA,North America
# 332 jesus st                    NA
